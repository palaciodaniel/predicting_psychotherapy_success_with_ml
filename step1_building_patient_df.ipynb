# %% [markdown]
# # Machine Learning - Predicting Treatment Abandonment with scikit learn
# By **Daniel Palacio** (github.com/palaciodaniel) - 2020

# %% [markdown]
# ## STEP ONE - Building the DataFrame
#
# In order to build the table, we will need to have the Faker package installed. For obvious privacy reasons, the use of real patient data has been ruled out, so we will build a fictional DataFrame from scratch. In case you do not have the Faker package installed, please remove the "#" sign on the following cell and Run it.
#
# **DO NOT RUN THE REST OF THE CELLS, OTHERWISE THEIR OUTPUT WILL BE LOST.**

# %%
# pip install Faker

# %% [markdown]
# 1.  We import Faker and "random" libraries. We will use Faker to create two columns: "Name" and "Gender" ([M]ale and [F]emale). As for "random", we will use it to generate a column with ages from 18 to 85.
#
#     All the information will be stored in a list of lists (with every nested list representing a single observation). We will generate 100 observations, so the list should have that length.
#
#     Notice that for both Faker and "random" we will be using seeds, so that we obtain the same results every time.

# %%
from faker import Faker
import random

fake = Faker()
Faker.seed(24)

names_list = []

for i in range(100):
    random.seed(i)
    profile = fake.simple_profile()
    names_list.extend([[profile["name"], profile["sex"], random.randint(18, 85)]])

print("List length:", len(names_list), "\n")
print(names_list)
# Out:
# List length: 100
#
# [['Clayton Murillo', 'M', 67], ['Mary Johnson', 'F', 35], ['Angela Taylor', 'F', 25], ['Sarah Massey', 'F', 48], ['Joseph Lam', 'M', 48], ['Corey Hernandez', 'M', 50], ['Colton Bryan', 'M', 28], ['Kristy Young', 'F', 59], ['Carla Bradford', 'F', 47], ['Jane Brown', 'F', 77], ['Traci Alvarez', 'F', 22], ['Jennifer Sexton', 'F', 75], ['Miss Jenna Beasley', 'F', 78], ['Matthew Francis', 'M', 51], ['Krystal Robinson', 'F', 31], ['Christopher Campbell', 'M', 44], ['Cassandra Becker', 'F', 64], ['Christopher Harrison', 'M', 84], ['Alex Morales', 'M', 41], ['Jerry Rodgers', 'M', 23], ['Matthew Davis', 'M', 37], ['Ralph Stewart', 'M', 39], ['Beth Rodriguez', 'F', 35], ['Eduardo Cordova', 'M', 55], ['Preston Long', 'M', 67], ['Alyssa Stein', 'F', 66], ['Terri Hernandez', 'F', 43], ['Peggy Bowen', 'F', 79], ['Jose Leblanc', 'M', 32], ['Wanda Wilson', 'F', 27], ['Natasha Holt', 'F', 55], ['Dr. Mary Neal', 'F', 19], ['Eddie Buckley', 'M', 27], ['Jose Ward', 'M', 39], ['Justin Lee', 'M', 85], ['Calvin Brandt', 'M', 60], ['Robin Nelson', 'F', 60], ['Megan Chavez', 'F', 29], ['James Cook', 'M', 71], ['Anthony Beck', 'M', 44], ['Christopher Becker', 'M', 76], ['Lisa Hendricks', 'F', 66], ['Dylan Neal', 'M', 32], ['William Li', 'M', 22], ['Danielle Lawson', 'F', 70], ['Michael Ross', 'M', 52], ['Arthur Mccarthy', 'M', 27], ['Kristen Day', 'F', 63], ['Jacob Coleman', 'M', 58], ['Carla Thompson', 'F', 26], ['Dawn Russell', 'F', 81], ['Daniel Flowers', 'M', 49], ['Kevin Perez', 'M', 52], ['Nancy Miller', 'F', 45], ['Benjamin Wolf', 'M', 35], ['Jeffrey Davidson', 'M', 29], ['Antonio Castaneda', 'M', 19], ['Scott Glass', 'M', 23], ['Regina Contreras', 'F', 43], ['Nicole Russell', 'F', 46], ['Mary Sanchez', 'F', 57], ['James Spence', 'M', 81], ['Sara Allen', 'F', 40], ['Stanley Cole', 'M', 74], ['Sandra Oneill', 'F', 78], ['Rhonda Davis', 'F', 71], ['Angela Parker', 'F', 27], ['Kristin King', 'F', 27], ['Deborah Stanley', 'F', 77], ['Richard Reed', 'M', 22], ['Julie Townsend', 'F', 33], ['Tammy Wilcox', 'F', 59], ['Lindsey Wong', 'F', 27], ['Christine Savage', 'F', 53], ['Bradley Alvarez', 'M', 83], ['Melissa Gomez', 'F', 75], ['Christopher Bates', 'M', 65], ['Anthony Hernandez', 'M', 50], ['Jacqueline Finley', 'F', 42], ['Christy Shepard', 'F', 36], ['Margaret Greer', 'F', 52], ['Ryan Spencer', 'M', 82], ['John Hart', 'M', 36], ['Brittany Dunn', 'F', 81], ['Jasmine Rodriguez', 'F', 54], ['Matthew Garcia', 'M', 43], ['April Serrano', 'F', 21], ['Richard Bell', 'M', 36], ['Kayla Brock', 'F', 68], ['Shannon Perez', 'F', 28], ['Natalie Mason', 'F', 44], ['Bryan Knox', 'M', 28], ['Sara Anderson', 'F', 71], ['Jacqueline Lyons', 'F', 81], ['Cheryl Reynolds', 'F', 41], ['Jeff Simmons', 'M', 83], ['Ryan Kirk', 'M', 65], ['Harry Hayes', 'M', 42], ['Jonathan Huff', 'M', 63], ['Allen Smith', 'M', 69]]

# %% [markdown]
# 2.  We will now generate columns for different fictional features. The use of a real test was dismissed to avoid potential copyright infringements, but still, this whole demonstration shows how it is perfectly feasible to implement a Machine Learning approach on a situation like this.
#
#     Obviously, every observation feature will be filled at "random", from a list of three possible choices: "Low", "Medium" and "High".
#
#     A brief description of some of the non-obvious (and obviously fictional) features:
#
#     * **Neuroticism:** Indicates how much the adaptation to everyday's life demands was compromised.
#     * **Resourcefulness:** This one not only includes intelligence, but also any other resource that can be used to fulfill the treatment's objectives (i.e.: salary, social skills, etc.).
#     * **Social Expectation:** Measures the perceived level of "pressure" the patient has from the most immediate social circles to overcome the problem/mental disorder.
#     * **Introspection:** The ability to understand and assess all the changes the treatment produces on the patient's well-being and general quality of life.
#     * **Victimhood:** Unlike the previous features, this one is either "True" or "False". If "True", the patient tends to believe life will always be inherently "harsh", while people on the opposite side tend to be more "combative" and understand that change is possible.

# %%
neuroticism = []
motivation = []
resourcefulness = []
social_expectation = []
introspection = []
discipline = []
victimhood = []

for i in range(100):
    random.seed(i)
    neuroticism.append(random.choice(["Low", "Medium", "High"]))
    motivation.append(random.choice(["Low", "Medium", "High"]))
    resourcefulness.append(random.choice(["Low", "Medium", "High"]))
    social_expectation.append(random.choice(["Low", "Medium", "High"]))
    introspection.append(random.choice(["Low", "Medium", "High"]))
    discipline.append(random.choice(["Low", "Medium", "High"]))
    victimhood.append(random.choice([True, False]))

# %% [markdown]
# 3. Now we import the pandas module and transform the nested lists from Step 1 into a proper DataFrame.
#
# ##### NOTE: The column 'Genre' should be 'Gender' or 'Sex'. This is a typing mistake. However, it was left like that to avoid having to re-execute Step 7, but it will be fixed for the second phase.

# %%
import pandas as pd

patient_df = pd.DataFrame(names_list, columns=["Name", "Genre", "Age"])
print(patient_df.head())
# Out:
#               Name Genre  Age
# 0  Clayton Murillo     M   67
# 1     Mary Johnson     F   35
# 2    Angela Taylor     F   25
# 3     Sarah Massey     F   48
# 4       Joseph Lam     M   48

# %% [markdown]
# 4. We also integrate the features into a DataFrame as well.

# %%
patient_df2 = pd.DataFrame(list(zip(neuroticism, motivation, resourcefulness,
                                    social_expectation, introspection, discipline, victimhood)),
                          columns = ["Neuroticism", "Motivation", "Resourcefulness", "Social Expectation",
                                     "Introspection", "Discipline", "Victimhood"])

print("DataFrame's shape:", patient_df2.shape, "\n")
print(patient_df2.head())
# Out:
# DataFrame's shape: (100, 7)
#
#   Neuroticism Motivation Resourcefulness Social Expectation Introspection  \
# 0      Medium     Medium             Low             Medium          High
# 1         Low       High             Low             Medium           Low
# 2         Low        Low             Low             Medium           Low
# 3         Low       High            High                Low        Medium
# 4         Low     Medium             Low               High        Medium
#
#   Discipline  Victimhood
# 0     Medium       False
# 1     Medium       False
# 2       High       False
# 3       High       False
# 4     Medium        True

# %% [markdown]
# 5. We combine the DataFrames from both previous steps into a single one.

# %%
patient_final_df = pd.concat([patient_df, patient_df2], axis = 1)

print("Final DataFrame's shape:", patient_final_df.shape, "\n")
print(patient_final_df.head())
# Out:
# Final DataFrame's shape: (100, 10)
#
#               Name Genre  Age Neuroticism Motivation Resourcefulness  \
# 0  Clayton Murillo     M   67      Medium     Medium             Low
# 1     Mary Johnson     F   35         Low       High             Low
# 2    Angela Taylor     F   25         Low        Low             Low
# 3     Sarah Massey     F   48         Low       High            High
# 4       Joseph Lam     M   48         Low     Medium             Low
#
#   Social Expectation Introspection Discipline  Victimhood
# 0             Medium          High     Medium       False
# 1             Medium           Low     Medium       False
# 2             Medium           Low       High       False
# 3                Low        Medium       High       False
# 4               High        Medium     Medium        True

# %% [markdown]
# 6.  We are ready to create the target column now. The following code prints every single observation and allows to input a "realistic" treatment's outcome based on all features. Did the patient finish the treatment?
#
#     After examining all the 100 observations, the selected outcomes will be appended to a list.

# %%
finished_treatment = []

for i in range(len(patient_final_df)):
    print(patient_final_df.loc[i, :])
    your_input = input("Finished treatment? (TRUE/FALSE): ")
    finished_treatment.append(your_input)

print(finished_treatment)
# Out:
# Name                  Clayton Murillo
# Genre                               M
# Age                                67
# Neuroticism                    Medium
# Motivation                     Medium
# Resourcefulness                   Low
# Social Expectation             Medium
# Introspection                    High
# Discipline                     Medium
# Victimhood                      False
# Name: 0, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Mary Johnson
# Genre                            F
# Age                             35
# Neuroticism                    Low
# Motivation                    High
# Resourcefulness                Low
# Social Expectation          Medium
# Introspection                  Low
# Discipline                  Medium
# Victimhood                   False
# Name: 1, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Angela Taylor
# Genre                             F
# Age                              25
# Neuroticism                     Low
# Motivation                      Low
# Resourcefulness                 Low
# Social Expectation           Medium
# Introspection                   Low
# Discipline                     High
# Victimhood                    False
# Name: 2, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Sarah Massey
# Genre                            F
# Age                             48
# Neuroticism                    Low
# Motivation                    High
# Resourcefulness               High
# Social Expectation             Low
# Introspection               Medium
# Discipline                    High
# Victimhood                   False
# Name: 3, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Joseph Lam
# Genre                          M
# Age                           48
# Neuroticism                  Low
# Motivation                Medium
# Resourcefulness              Low
# Social Expectation          High
# Introspection             Medium
# Discipline                Medium
# Victimhood                  True
# Name: 4, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Corey Hernandez
# Genre                               M
# Age                                50
# Neuroticism                      High
# Motivation                     Medium
# Resourcefulness                  High
# Social Expectation             Medium
# Introspection                    High
# Discipline                       High
# Victimhood                       True
# Name: 5, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Colton Bryan
# Genre                            M
# Age                             28
# Neuroticism                   High
# Motivation                     Low
# Resourcefulness             Medium
# Social Expectation          Medium
# Introspection                  Low
# Discipline                     Low
# Victimhood                    True
# Name: 6, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Kristy Young
# Genre                            F
# Age                             59
# Neuroticism                 Medium
# Motivation                     Low
# Resourcefulness             Medium
# Social Expectation            High
# Introspection                  Low
# Discipline                     Low
# Victimhood                    True
# Name: 7, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Carla Bradford
# Genre                              F
# Age                               47
# Neuroticism                      Low
# Motivation                    Medium
# Resourcefulness               Medium
# Social Expectation               Low
# Introspection                    Low
# Discipline                      High
# Victimhood                      True
# Name: 8, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Jane Brown
# Genre                          F
# Age                           77
# Neuroticism               Medium
# Motivation                  High
# Resourcefulness           Medium
# Social Expectation        Medium
# Introspection                Low
# Discipline                   Low
# Victimhood                  True
# Name: 9, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Traci Alvarez
# Genre                             F
# Age                              22
# Neuroticism                    High
# Motivation                      Low
# Resourcefulness              Medium
# Social Expectation           Medium
# Introspection                  High
# Discipline                      Low
# Victimhood                     True
# Name: 10, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Jennifer Sexton
# Genre                               F
# Age                                75
# Neuroticism                    Medium
# Motivation                       High
# Resourcefulness                Medium
# Social Expectation             Medium
# Introspection                    High
# Discipline                       High
# Victimhood                       True
# Name: 11, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Miss Jenna Beasley
# Genre                                  F
# Age                                   78
# Neuroticism                       Medium
# Motivation                        Medium
# Resourcefulness                     High
# Social Expectation                  High
# Introspection                       High
# Discipline                        Medium
# Victimhood                          True
# Name: 12, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Matthew Francis
# Genre                               M
# Age                                51
# Neuroticism                    Medium
# Motivation                     Medium
# Resourcefulness                  High
# Social Expectation               High
# Introspection                     Low
# Discipline                       High
# Victimhood                       True
# Name: 13, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Krystal Robinson
# Genre                                F
# Age                                 31
# Neuroticism                        Low
# Motivation                        High
# Resourcefulness                   High
# Social Expectation                High
# Introspection                     High
# Discipline                         Low
# Victimhood                       False
# Name: 14, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Christopher Campbell
# Genre                                    M
# Age                                     44
# Neuroticism                            Low
# Motivation                             Low
# Resourcefulness                       High
# Social Expectation                    High
# Introspection                          Low
# Discipline                             Low
# Victimhood                            True
# Name: 15, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Cassandra Becker
# Genre                                F
# Age                                 64
# Neuroticism                     Medium
# Motivation                      Medium
# Resourcefulness                 Medium
# Social Expectation              Medium
# Introspection                   Medium
# Discipline                         Low
# Victimhood                       False
# Name: 16, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Christopher Harrison
# Genre                                    M
# Age                                     84
# Neuroticism                           High
# Motivation                          Medium
# Resourcefulness                     Medium
# Social Expectation                  Medium
# Introspection                       Medium
# Discipline                             Low
# Victimhood                           False
# Name: 17, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Alex Morales
# Genre                            M
# Age                             41
# Neuroticism                    Low
# Motivation                     Low
# Resourcefulness               High
# Social Expectation          Medium
# Introspection               Medium
# Discipline                     Low
# Victimhood                    True
# Name: 18, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Jerry Rodgers
# Genre                             M
# Age                              23
# Neuroticism                    High
# Motivation                      Low
# Resourcefulness                High
# Social Expectation              Low
# Introspection                  High
# Discipline                      Low
# Victimhood                    False
# Name: 19, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Matthew Davis
# Genre                             M
# Age                              37
# Neuroticism                    High
# Motivation                     High
# Resourcefulness                 Low
# Social Expectation           Medium
# Introspection                  High
# Discipline                     High
# Victimhood                     True
# Name: 20, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Ralph Stewart
# Genre                             M
# Age                              39
# Neuroticism                     Low
# Motivation                   Medium
# Resourcefulness                High
# Social Expectation           Medium
# Introspection                  High
# Discipline                   Medium
# Victimhood                    False
# Name: 21, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Beth Rodriguez
# Genre                              F
# Age                               35
# Neuroticism                      Low
# Motivation                       Low
# Resourcefulness                  Low
# Social Expectation              High
# Introspection                 Medium
# Discipline                       Low
# Victimhood                      True
# Name: 22, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Eduardo Cordova
# Genre                               M
# Age                                55
# Neuroticism                    Medium
# Motivation                        Low
# Resourcefulness                   Low
# Social Expectation               High
# Introspection                  Medium
# Discipline                     Medium
# Victimhood                      False
# Name: 23, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Preston Long
# Genre                            M
# Age                             67
# Neuroticism                   High
# Motivation                  Medium
# Resourcefulness               High
# Social Expectation             Low
# Introspection                  Low
# Discipline                     Low
# Victimhood                    True
# Name: 24, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Alyssa Stein
# Genre                            F
# Age                             66
# Neuroticism                 Medium
# Motivation                     Low
# Resourcefulness                Low
# Social Expectation          Medium
# Introspection                 High
# Discipline                  Medium
# Victimhood                    True
# Name: 25, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Terri Hernandez
# Genre                               F
# Age                                43
# Neuroticism                      High
# Motivation                        Low
# Resourcefulness                  High
# Social Expectation                Low
# Introspection                  Medium
# Discipline                       High
# Victimhood                       True
# Name: 26, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Peggy Bowen
# Genre                           F
# Age                            79
# Neuroticism                  High
# Motivation                 Medium
# Resourcefulness              High
# Social Expectation         Medium
# Introspection              Medium
# Discipline                    Low
# Victimhood                   True
# Name: 27, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Jose Leblanc
# Genre                            M
# Age                             32
# Neuroticism                    Low
# Motivation                    High
# Resourcefulness                Low
# Social Expectation            High
# Introspection                 High
# Discipline                    High
# Victimhood                    True
# Name: 28, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Wanda Wilson
# Genre                            F
# Age                             27
# Neuroticism                   High
# Motivation                     Low
# Resourcefulness             Medium
# Social Expectation            High
# Introspection                 High
# Discipline                  Medium
# Victimhood                    True
# Name: 29, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Natasha Holt
# Genre                            F
# Age                             55
# Neuroticism                   High
# Motivation                  Medium
# Resourcefulness               High
# Social Expectation             Low
# Introspection                 High
# Discipline                    High
# Victimhood                    True
# Name: 30, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Dr. Mary Neal
# Genre                             F
# Age                              19
# Neuroticism                     Low
# Motivation                   Medium
# Resourcefulness                 Low
# Social Expectation           Medium
# Introspection                   Low
# Discipline                     High
# Victimhood                     True
# Name: 31, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Eddie Buckley
# Genre                             M
# Age                              27
# Neuroticism                     Low
# Motivation                      Low
# Resourcefulness                 Low
# Social Expectation           Medium
# Introspection                  High
# Discipline                      Low
# Victimhood                    False
# Name: 32, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Jose Ward
# Genre                         M
# Age                          39
# Neuroticism                High
# Motivation                  Low
# Resourcefulness            High
# Social Expectation          Low
# Introspection            Medium
# Discipline               Medium
# Victimhood                 True
# Name: 33, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Justin Lee
# Genre                          M
# Age                           85
# Neuroticism                 High
# Motivation                Medium
# Resourcefulness             High
# Social Expectation           Low
# Introspection                Low
# Discipline                   Low
# Victimhood                 False
# Name: 34, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Calvin Brandt
# Genre                             M
# Age                              60
# Neuroticism                    High
# Motivation                   Medium
# Resourcefulness                 Low
# Social Expectation             High
# Introspection                Medium
# Discipline                      Low
# Victimhood                    False
# Name: 35, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Robin Nelson
# Genre                            F
# Age                             60
# Neuroticism                 Medium
# Motivation                     Low
# Resourcefulness                Low
# Social Expectation          Medium
# Introspection                  Low
# Discipline                     Low
# Victimhood                    True
# Name: 36, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Megan Chavez
# Genre                            F
# Age                             29
# Neuroticism                   High
# Motivation                    High
# Resourcefulness                Low
# Social Expectation            High
# Introspection                 High
# Discipline                    High
# Victimhood                    True
# Name: 37, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  James Cook
# Genre                          M
# Age                           71
# Neuroticism                 High
# Motivation                Medium
# Resourcefulness           Medium
# Social Expectation          High
# Introspection                Low
# Discipline                   Low
# Victimhood                 False
# Name: 38, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Anthony Beck
# Genre                            M
# Age                             44
# Neuroticism                    Low
# Motivation                  Medium
# Resourcefulness             Medium
# Social Expectation             Low
# Introspection                  Low
# Discipline                     Low
# Victimhood                   False
# Name: 39, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Christopher Becker
# Genre                                  M
# Age                                   76
# Neuroticism                       Medium
# Motivation                          High
# Resourcefulness                     High
# Social Expectation                   Low
# Introspection                        Low
# Discipline                        Medium
# Victimhood                          True
# Name: 40, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Lisa Hendricks
# Genre                              F
# Age                               66
# Neuroticism                   Medium
# Motivation                    Medium
# Resourcefulness                  Low
# Social Expectation               Low
# Introspection                 Medium
# Discipline                      High
# Victimhood                     False
# Name: 41, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Dylan Neal
# Genre                          M
# Age                           32
# Neuroticism                 High
# Motivation                   Low
# Resourcefulness              Low
# Social Expectation          High
# Introspection             Medium
# Discipline                   Low
# Victimhood                  True
# Name: 42, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  William Li
# Genre                          M
# Age                           22
# Neuroticism                  Low
# Motivation                Medium
# Resourcefulness             High
# Social Expectation           Low
# Introspection             Medium
# Discipline                Medium
# Victimhood                  True
# Name: 43, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Danielle Lawson
# Genre                               F
# Age                                70
# Neuroticism                    Medium
# Motivation                       High
# Resourcefulness                  High
# Social Expectation               High
# Introspection                     Low
# Discipline                        Low
# Victimhood                      False
# Name: 44, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Michael Ross
# Genre                            M
# Age                             52
# Neuroticism                 Medium
# Motivation                  Medium
# Resourcefulness             Medium
# Social Expectation          Medium
# Introspection                  Low
# Discipline                  Medium
# Victimhood                   False
# Name: 45, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Arthur Mccarthy
# Genre                               M
# Age                                27
# Neuroticism                       Low
# Motivation                     Medium
# Resourcefulness                   Low
# Social Expectation               High
# Introspection                    High
# Discipline                        Low
# Victimhood                       True
# Name: 46, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Kristen Day
# Genre                           F
# Age                            63
# Neuroticism                Medium
# Motivation                    Low
# Resourcefulness            Medium
# Social Expectation           High
# Introspection              Medium
# Discipline                   High
# Victimhood                  False
# Name: 47, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Jacob Coleman
# Genre                             M
# Age                              58
# Neuroticism                    High
# Motivation                   Medium
# Resourcefulness                 Low
# Social Expectation             High
# Introspection                  High
# Discipline                     High
# Victimhood                    False
# Name: 48, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Carla Thompson
# Genre                              F
# Age                               26
# Neuroticism                      Low
# Motivation                    Medium
# Resourcefulness               Medium
# Social Expectation               Low
# Introspection                 Medium
# Discipline                      High
# Victimhood                      True
# Name: 49, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Dawn Russell
# Genre                            F
# Age                             81
# Neuroticism                 Medium
# Motivation                  Medium
# Resourcefulness             Medium
# Social Expectation            High
# Introspection                  Low
# Discipline                    High
# Victimhood                   False
# Name: 50, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Daniel Flowers
# Genre                              M
# Age                               49
# Neuroticism                      Low
# Motivation                      High
# Resourcefulness                 High
# Social Expectation               Low
# Introspection                    Low
# Discipline                       Low
# Victimhood                     False
# Name: 51, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Kevin Perez
# Genre                           M
# Age                            52
# Neuroticism                Medium
# Motivation                    Low
# Resourcefulness              High
# Social Expectation           High
# Introspection              Medium
# Discipline                 Medium
# Victimhood                  False
# Name: 52, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Nancy Miller
# Genre                            F
# Age                             45
# Neuroticism                   High
# Motivation                     Low
# Resourcefulness             Medium
# Social Expectation            High
# Introspection                 High
# Discipline                  Medium
# Victimhood                   False
# Name: 53, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Benjamin Wolf
# Genre                             M
# Age                              35
# Neuroticism                     Low
# Motivation                   Medium
# Resourcefulness                High
# Social Expectation           Medium
# Introspection                Medium
# Discipline                   Medium
# Victimhood                    False
# Name: 54, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Jeffrey Davidson
# Genre                                M
# Age                                 29
# Neuroticism                        Low
# Motivation                         Low
# Resourcefulness                    Low
# Social Expectation                High
# Introspection                   Medium
# Discipline                         Low
# Victimhood                        True
# Name: 55, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Antonio Castaneda
# Genre                                 M
# Age                                  19
# Neuroticism                        High
# Motivation                          Low
# Resourcefulness                  Medium
# Social Expectation                 High
# Introspection                      High
# Discipline                       Medium
# Victimhood                        False
# Name: 56, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Scott Glass
# Genre                           M
# Age                            23
# Neuroticism                   Low
# Motivation                 Medium
# Resourcefulness              High
# Social Expectation           High
# Introspection                 Low
# Discipline                    Low
# Victimhood                  False
# Name: 57, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Regina Contreras
# Genre                                F
# Age                                 43
# Neuroticism                       High
# Motivation                         Low
# Resourcefulness                    Low
# Social Expectation                High
# Introspection                     High
# Discipline                         Low
# Victimhood                        True
# Name: 58, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Nicole Russell
# Genre                              F
# Age                               46
# Neuroticism                      Low
# Motivation                       Low
# Resourcefulness                 High
# Social Expectation            Medium
# Introspection                    Low
# Discipline                       Low
# Victimhood                     False
# Name: 59, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Mary Sanchez
# Genre                            F
# Age                             57
# Neuroticism                 Medium
# Motivation                  Medium
# Resourcefulness               High
# Social Expectation             Low
# Introspection               Medium
# Discipline                     Low
# Victimhood                   False
# Name: 60, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  James Spence
# Genre                            M
# Age                             81
# Neuroticism                 Medium
# Motivation                     Low
# Resourcefulness               High
# Social Expectation             Low
# Introspection               Medium
# Discipline                  Medium
# Victimhood                   False
# Name: 61, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Sara Allen
# Genre                          F
# Age                           40
# Neuroticism                 High
# Motivation                   Low
# Resourcefulness              Low
# Social Expectation           Low
# Introspection             Medium
# Discipline                Medium
# Victimhood                 False
# Name: 62, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Stanley Cole
# Genre                            M
# Age                             74
# Neuroticism                 Medium
# Motivation                  Medium
# Resourcefulness             Medium
# Social Expectation          Medium
# Introspection               Medium
# Discipline                    High
# Victimhood                    True
# Name: 63, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Sandra Oneill
# Genre                             F
# Age                              78
# Neuroticism                  Medium
# Motivation                      Low
# Resourcefulness                High
# Social Expectation             High
# Introspection                Medium
# Discipline                     High
# Victimhood                     True
# Name: 64, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Rhonda Davis
# Genre                            F
# Age                             71
# Neuroticism                 Medium
# Motivation                  Medium
# Resourcefulness             Medium
# Social Expectation            High
# Introspection                  Low
# Discipline                  Medium
# Victimhood                   False
# Name: 65, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Angela Parker
# Genre                             F
# Age                              27
# Neuroticism                     Low
# Motivation                   Medium
# Resourcefulness              Medium
# Social Expectation              Low
# Introspection                Medium
# Discipline                   Medium
# Victimhood                    False
# Name: 66, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Kristin King
# Genre                            F
# Age                             27
# Neuroticism                    Low
# Motivation                     Low
# Resourcefulness             Medium
# Social Expectation          Medium
# Introspection               Medium
# Discipline                  Medium
# Victimhood                   False
# Name: 67, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Deborah Stanley
# Genre                               F
# Age                                77
# Neuroticism                      High
# Motivation                     Medium
# Resourcefulness                  High
# Social Expectation               High
# Introspection                    High
# Discipline                        Low
# Victimhood                       True
# Name: 68, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Richard Reed
# Genre                            M
# Age                             22
# Neuroticism                   High
# Motivation                     Low
# Resourcefulness                Low
# Social Expectation             Low
# Introspection                  Low
# Discipline                    High
# Victimhood                   False
# Name: 69, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Julie Townsend
# Genre                              F
# Age                               33
# Neuroticism                      Low
# Motivation                    Medium
# Resourcefulness                 High
# Social Expectation            Medium
# Introspection                 Medium
# Discipline                       Low
# Victimhood                     False
# Name: 70, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Tammy Wilcox
# Genre                            F
# Age                             59
# Neuroticism                 Medium
# Motivation                    High
# Resourcefulness               High
# Social Expectation             Low
# Introspection               Medium
# Discipline                     Low
# Victimhood                    True
# Name: 71, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Lindsey Wong
# Genre                            F
# Age                             27
# Neuroticism                    Low
# Motivation                    High
# Resourcefulness               High
# Social Expectation             Low
# Introspection               Medium
# Discipline                    High
# Victimhood                   False
# Name: 72, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Christine Savage
# Genre                                F
# Age                                 53
# Neuroticism                     Medium
# Motivation                         Low
# Resourcefulness                   High
# Social Expectation              Medium
# Introspection                     High
# Discipline                         Low
# Victimhood                       False
# Name: 73, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Bradley Alvarez
# Genre                               M
# Age                                83
# Neuroticism                      High
# Motivation                       High
# Resourcefulness                   Low
# Social Expectation             Medium
# Introspection                     Low
# Discipline                     Medium
# Victimhood                       True
# Name: 74, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Melissa Gomez
# Genre                             F
# Age                              75
# Neuroticism                  Medium
# Motivation                     High
# Resourcefulness              Medium
# Social Expectation           Medium
# Introspection                   Low
# Discipline                     High
# Victimhood                    False
# Name: 75, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Christopher Bates
# Genre                                 M
# Age                                  65
# Neuroticism                      Medium
# Motivation                       Medium
# Resourcefulness                  Medium
# Social Expectation                  Low
# Introspection                    Medium
# Discipline                          Low
# Victimhood                        False
# Name: 76, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Anthony Hernandez
# Genre                                 M
# Age                                  50
# Neuroticism                      Medium
# Motivation                       Medium
# Resourcefulness                     Low
# Social Expectation                  Low
# Introspection                       Low
# Discipline                          Low
# Victimhood                        False
# Name: 77, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Jacqueline Finley
# Genre                                 F
# Age                                  42
# Neuroticism                         Low
# Motivation                          Low
# Resourcefulness                  Medium
# Social Expectation                 High
# Introspection                      High
# Discipline                       Medium
# Victimhood                        False
# Name: 78, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Christy Shepard
# Genre                               F
# Age                                36
# Neuroticism                       Low
# Motivation                     Medium
# Resourcefulness                Medium
# Social Expectation               High
# Introspection                     Low
# Discipline                        Low
# Victimhood                       True
# Name: 79, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Margaret Greer
# Genre                              F
# Age                               52
# Neuroticism                   Medium
# Motivation                    Medium
# Resourcefulness                 High
# Social Expectation              High
# Introspection                 Medium
# Discipline                    Medium
# Victimhood                     False
# Name: 80, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Ryan Spencer
# Genre                            M
# Age                             82
# Neuroticism                   High
# Motivation                  Medium
# Resourcefulness             Medium
# Social Expectation            High
# Introspection                 High
# Discipline                  Medium
# Victimhood                   False
# Name: 81, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  John Hart
# Genre                         M
# Age                          36
# Neuroticism                 Low
# Motivation               Medium
# Resourcefulness            High
# Social Expectation       Medium
# Introspection               Low
# Discipline                  Low
# Victimhood                False
# Name: 82, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Brittany Dunn
# Genre                             F
# Age                              81
# Neuroticism                  Medium
# Motivation                   Medium
# Resourcefulness                 Low
# Social Expectation              Low
# Introspection                Medium
# Discipline                      Low
# Victimhood                     True
# Name: 83, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Jasmine Rodriguez
# Genre                                 F
# Age                                  54
# Neuroticism                        High
# Motivation                       Medium
# Resourcefulness                     Low
# Social Expectation               Medium
# Introspection                       Low
# Discipline                         High
# Victimhood                        False
# Name: 84, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Matthew Garcia
# Genre                              M
# Age                               43
# Neuroticism                      Low
# Motivation                      High
# Resourcefulness                 High
# Social Expectation               Low
# Introspection                 Medium
# Discipline                       Low
# Victimhood                      True
# Name: 85, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  April Serrano
# Genre                             F
# Age                              21
# Neuroticism                     Low
# Motivation                     High
# Resourcefulness              Medium
# Social Expectation             High
# Introspection                   Low
# Discipline                      Low
# Victimhood                    False
# Name: 86, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Richard Bell
# Genre                            M
# Age                             36
# Neuroticism                    Low
# Motivation                    High
# Resourcefulness                Low
# Social Expectation            High
# Introspection                  Low
# Discipline                  Medium
# Victimhood                   False
# Name: 87, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Kayla Brock
# Genre                           F
# Age                            68
# Neuroticism                Medium
# Motivation                    Low
# Resourcefulness            Medium
# Social Expectation            Low
# Introspection                High
# Discipline                    Low
# Victimhood                   True
# Name: 88, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Shannon Perez
# Genre                             F
# Age                              28
# Neuroticism                     Low
# Motivation                     High
# Resourcefulness                High
# Social Expectation           Medium
# Introspection                   Low
# Discipline                   Medium
# Victimhood                     True
# Name: 89, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Natalie Mason
# Genre                             F
# Age                              44
# Neuroticism                     Low
# Motivation                     High
# Resourcefulness                 Low
# Social Expectation           Medium
# Introspection                  High
# Discipline                     High
# Victimhood                    False
# Name: 90, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Bryan Knox
# Genre                          M
# Age                           28
# Neuroticism                  Low
# Motivation                  High
# Resourcefulness              Low
# Social Expectation          High
# Introspection               High
# Discipline                   Low
# Victimhood                 False
# Name: 91, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Sara Anderson
# Genre                             F
# Age                              71
# Neuroticism                  Medium
# Motivation                     High
# Resourcefulness                High
# Social Expectation             High
# Introspection                  High
# Discipline                     High
# Victimhood                    False
# Name: 92, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Jacqueline Lyons
# Genre                                F
# Age                                 81
# Neuroticism                     Medium
# Motivation                        High
# Resourcefulness                   High
# Social Expectation              Medium
# Introspection                      Low
# Discipline                         Low
# Victimhood                       False
# Name: 93, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Cheryl Reynolds
# Genre                               F
# Age                                41
# Neuroticism                      High
# Motivation                        Low
# Resourcefulness                   Low
# Social Expectation             Medium
# Introspection                  Medium
# Discipline                     Medium
# Victimhood                       True
# Name: 94, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Jeff Simmons
# Genre                            M
# Age                             83
# Neuroticism                   High
# Motivation                    High
# Resourcefulness               High
# Social Expectation            High
# Introspection                  Low
# Discipline                  Medium
# Victimhood                    True
# Name: 95, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Ryan Kirk
# Genre                         M
# Age                          65
# Neuroticism              Medium
# Motivation               Medium
# Resourcefulness            High
# Social Expectation       Medium
# Introspection               Low
# Discipline                  Low
# Victimhood                False
# Name: 96, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Harry Hayes
# Genre                           M
# Age                            42
# Neuroticism                   Low
# Motivation                 Medium
# Resourcefulness            Medium
# Social Expectation            Low
# Introspection                High
# Discipline                    Low
# Victimhood                   True
# Name: 97, dtype: object
# Finished treatment? (TRUE/FALSE): False
# Name                  Jonathan Huff
# Genre                             M
# Age                              63
# Neuroticism                  Medium
# Motivation                     High
# Resourcefulness                 Low
# Social Expectation           Medium
# Introspection                Medium
# Discipline                      Low
# Victimhood                    False
# Name: 98, dtype: object
# Finished treatment? (TRUE/FALSE): True
# Name                  Allen Smith
# Genre                           M
# Age                            69
# Neuroticism                Medium
# Motivation                 Medium
# Resourcefulness               Low
# Social Expectation           High
# Introspection                 Low
# Discipline                    Low
# Victimhood                   True
# Name: 99, dtype: object
# Finished treatment? (TRUE/FALSE): False
# ['False', 'True', 'False', 'True', 'False', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'True', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'True', 'True', 'False', 'False', 'True', 'False', 'False', 'False', 'False', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'False', 'False', 'True', 'True', 'False', 'True', 'True', 'True', 'False', 'True', 'True', 'False', 'True', 'False', 'False', 'False', 'True', 'False', 'False', 'False', 'True', 'True', 'True', 'True', 'False', 'False', 'False', 'False', 'False', 'True', 'False']

# %% [markdown]
# 7. We append the target column to the previous combined DataFrame. It is officially finished now.

# %%
patient_final_df["Finished"] = finished_treatment
print(patient_final_df.head())
# Out:
#               Name Genre  Age Neuroticism Motivation Resourcefulness  \
# 0  Clayton Murillo     M   67      Medium     Medium             Low
# 1     Mary Johnson     F   35         Low       High             Low
# 2    Angela Taylor     F   25         Low        Low             Low
# 3     Sarah Massey     F   48         Low       High            High
# 4       Joseph Lam     M   48         Low     Medium             Low
#
#   Social Expectation Introspection Discipline  Victimhood Finished
# 0             Medium          High     Medium       False    False
# 1             Medium           Low     Medium       False     True
# 2             Medium           Low       High       False    False
# 3                Low        Medium       High       False     True
# 4               High        Medium     Medium        True    False

# %% [markdown]
# 8. We save the DataFrame to a CSV file, ready to be cleaned and prepared on Step 2...

# %%
patient_final_df.to_csv("df_patients.csv", index = True)
